# %%
#format:
json = {
  "limit": 500,
  "filter": {
    "must": [{ "has_id": [100100, 200100, 300100, 40100,  500100, 600100, 700100, 800100, 900100, 1000100, 1100100] }]
  }
}

# %%
max_id = 190

out_str = """
{
  "limit": 500,
  "filter": {
    "must": [{ "has_id": [
"""

for id in range(1, max_id):
    vector_id = id * 10000 + 100
    out_str += str(vector_id) + ", "

out_str += """
    ]}]
    }
}
"""

print(out_str)
# Out:
# {
#   "limit": 500,
#   "filter": {
#     "must": [{ "has_id": [
# ...
